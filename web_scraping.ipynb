# %% [markdown]
# webscraping from https://www.imhpa.gob.pa/es/datos-diarios?estacion=1&mes=1&ano=2025 Tocumen enero 2024

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.imhpa.gob.pa/es/datos-diarios?estacion=1&mes=1&ano=2025"
headers = {"User-Agent": "Mozilla/5.0"}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')
tabla = soup.find('table', {'class': 'table'})
filas = tabla.find_all('tr')

data = []
for fila in filas:
    columnas = fila.find_all(['th', 'td'])
    fila_texto = [col.text.strip() for col in columnas]
    data.append(fila_texto)

df = pd.DataFrame(data)

columnas_finales = [
    "Día",
    "Temperatura Máxima (°C)",
    "Temperatura Mínima (°C)",
    "Temperatura Promedio (°C)",
    "Lluvia Mes Actual (mm)",
    "Lluvia Acumulada(mm)",
    "Lluvia Promedio (mm)",
    "Lluvia Acumulada Promedio Histórico (mm)",
    "Viento Velocidad Máxima (Km/h)",
    "Viento Dirección Máxima (°)",
    "Viento Hora Máxima",
    "Dirección del Viento"
]

df.columns = columnas_finales
df = df.iloc[2:].reset_index(drop=True) 

df["Día"] = pd.to_numeric(df["Día"], errors='coerce')
df = df[df["Día"].between(1, 31)].reset_index(drop=True)

print(df)
# Out:
#      Día Temperatura Máxima (°C) Temperatura Mínima (°C)  \
# 0    1.0                    27.6                    24.2
# 1    2.0                    28.1                    22.8
# 2    3.0                    29.9                    23.8
# 3    4.0                    27.4                    23.8
# 4    5.0                    29.6                    23.2
# 5    6.0                    29.4                    23.9
# 6    7.0                    31.8                    23.3
# 7    8.0                      32                    23.9
# 8    9.0                    32.2                    22.8
# 9   10.0                    30.7                    22.2
# 10  11.0                    30.4                      23
# 11  12.0                    32.6                    21.5
# 12  13.0                    31.9                    21.8
# 13  14.0                    32.2                    22.9
# 14  15.0                    31.8                    21.9
# 15  16.0                    31.7                    21.5
# 16  17.0                    31.8                    23.3
# 17  18.0                    33.5                      22
# 18  19.0                    33.2                    22.4
# 19  20.0                    33.6                    22.6
# 20  21.0                    33.2                    23.1
# 21  22.0                    33.1                    23.3
# 22  23.0                    33.4                      22
# 23  24.0                    31.4                    22.2
# 24  25.0                    31.5                    23.5
# 25  26.0                    32.3                    22.6
# 26  27.0                    32.9                    22.4
# 27  28.0                    32.9                    22.6
# 28  29.0                    33.2                    23.1
# 29  30.0                      34                    27.7
# 30  31.0                    34.5                    22.5
#
#    Temperatura Promedio (°C) Lluvia Mes Actual (mm) Lluvia Acumulada(mm)  \
# 0                       25.9                    2.8                  2.8
# 1                       25.5                    1.4                  4.2
# 2                       26.9                   23.0                 27.2
# 3                       25.6                   13.3                 40.5
# 4                       26.4                   14.9                 55.4
# 5                       26.7                    4.8                 60.2
# 6                       27.6                    0.0                 60.2
# 7                         28                    0.0                 60.2
# 8                       27.5                    0.0                 60.2
# 9                       26.5                    0.0                 60.2
# 10                      26.7                    0.0                 60.2
# 11                      27.1                    0.0                 60.2
# 12                      26.9                    0.0                 60.2
# 13                      27.6                    0.0                 60.2
# 14                      26.9                    0.0                 60.2
# 15                      26.6                    0.0                 60.2
# 16                      27.6                    0.0                 60.2
# 17                      27.8                    0.0                 60.2
# 18                      27.8                    0.0                 60.2
# 19                      28.1                    0.0                 60.2
# 20                      28.2                    0.0                 60.2
# 21                      28.2                    0.0                 60.2
# 22                      27.7                    0.0                 60.2
# 23                      26.8                    0.0                 60.2
# 24                      27.5                    1.8                 62.0
# 25                      27.5                    0.0                 62.0
# 26                      27.7                    0.0                 62.0
# 27                      27.8                    0.0                 62.0
# 28                      28.2                    0.0                 62.0
# 29                      30.9                    0.0                 62.0
# 30                      28.5                    0.0                 62.0
#
#    Lluvia Promedio (mm) Lluvia Acumulada Promedio Histórico (mm)  \
# 0                   0.5                                      0.5
# 1                   2.2                                      2.7
# 2                   2.0                                      4.7
# 3                   1.7                                      6.4
# 4                   2.0                                      8.4
# 5                   1.3                                      9.7
# 6                   0.2                                      9.9
# 7                   3.8                                     13.7
# 8                   0.7                                     14.4
# 9                   2.4                                     16.8
# 10                  0.1                                     16.9
# 11                  0.7                                     17.6
# 12                  1.8                                     19.4
# 13                  1.0                                     20.4
# 14                  1.3                                     21.7
# 15                  0.2                                     21.9
# 16                  0.4                                     22.3
# 17                  0.7                                     23.0
# 18                  1.0                                     24.0
# 19                  2.0                                     26.0
# 20                  0.0                                     26.0
# 21                  0.2                                     26.2
# 22                  0.2                                     26.4
# 23                  0.0                                     26.4
# 24                  0.0                                     26.4
# 25                  0.0                                     26.4
# 26                  0.2                                     26.6
# 27                  0.0                                     26.6
# 28                  0.2                                     26.8
# 29                  0.1                                     26.9
# 30                  0.0                                     26.9
#
#    Viento Velocidad Máxima (Km/h) Viento Dirección Máxima (°)  \
# 0                            25.9                          20
# 1                            18.5                         300
# 2                            18.5                         280
# 3                            18.5                         280
# 4                            16.7                          50
# 5                            22.2                         290
# 6                            18.5                          40
# 7                            26.0                          30
# 8                            22.2                          20
# 9                            12.9                         200
# 10                           16.7                          60
# 11                           18.5                          40
# 12                           20.4                          30
# 13
# 14                           29.6                          40
# 15
# 16                           27.8                          30
# 17                           14.8                         180
# 18                           14.8                          60
# 19                           18.5                          60
# 20                           14.8                         180
# 21                           20.4                          20
# 22                           24.1                          30
# 23                           18.5                          30
# 24                           55.5                          50
# 25                           25.9                          20
# 26                           18.5                          10
# 27                           27.8                          10
# 28                           22.2                          40
# 29                           22.2                          20
# 30                           18.5                          10
#
#    Viento Hora Máxima Dirección del Viento
# 0               13:00                Norte
# 1               16:00                Oeste
# 2               17:00                Oeste
# 3               13:00                Oeste
# 4               15:00                Oeste
# 5               17:00                Oeste
# 6               12:30                Oeste
# 7               12:00              Noreste
# 8               15:00              Noreste
# 9               15:00                Norte
# 10              13:00              Noreste
# 11              14:00             Variable
# 12              15:00             Noroeste
# 13                                   Oeste
# 14              13:00              Noreste
# 15                                   Norte
# 16              13:00              Noreste
# 17              16:00              Sureste
# 18              12:00                Oeste
# 19              13:00                Norte
# 20              13:00                Oeste
# 21              16:00              Noreste
# 22              11:00              Noreste
# 23              17:00             Suroeste
# 24              12:00              Noreste
# 25              12:00                Norte
# 26              11:00              Noreste
# 27              12:00              Noreste
# 28              14:00                Oeste
# 29              14:00                Norte
# 30              15:00             Variable
